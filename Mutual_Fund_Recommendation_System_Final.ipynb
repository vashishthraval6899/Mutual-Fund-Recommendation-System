# %% [markdown]
# # **Mutual Funds Recommendation System**
#
# # By Vashishth Raval
#
# Contact: [Email](mailto:vraval765@gmail.com) | [Linkedin](https://www.linkedin.com/in/vashishthraval) | [Github](https://github.com/vashishthraval6899)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# # **1. About Data**
# The dataset used in this project has been collected from "[RupeeVest](https://www.rupeevest.com/)"
# ,an online investment and research platform for Mutual Funds and Corporate Fixed Deposits in India.
# It includes data for all major categories of mutual funds — Equity, Debt, Hybrid, and Commodity funds — that have been rated by RupeeVest.

# %% [markdown]
# ---

# %% [markdown]
# # **2. Feature Descriptions**
#
#
# | **Column Name**                 | **Description**                                                                                                                                                |
# | ------------------------------- | -------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | **Funds**                       | The official name of the mutual fund scheme.                                                                                                                   |
# | **Fund Manager**                | The person responsible for making investment decisions and managing the fund’s portfolio.                                                                      |
# | **Category**                    | The classification of the mutual fund based on its investment strategy (e.g., Equity, Hybrid, Debt).                                                           |
# | **RupeeVestRating**             | Rating assigned by RupeeVest (on a scale or as ‘Unrated’), indicating the fund’s relative performance and risk-adjusted returns.                               |
# | **AUM (in Rs. cr)**             | Assets Under Management – the total market value of all assets held by the fund, measured in crores of rupees. It indicates fund size and investor confidence. |
# | **Expense Ratio (%)**           | The annual percentage of a fund’s total assets that is used to cover management and operational expenses. Lower ratios are usually preferred.                  |
# | **Fund Type**                   | Indicates whether the fund is *Open Ended* (can be bought/sold anytime) or *Closed Ended* (available only during specific periods).                            |
# | **Inception Date**              | The date when the fund was launched. Helps in evaluating the fund’s track record.                                                                              |
# | **Benchmark Index**             | The market index used to compare the fund’s performance (e.g., NIFTY 50, CRISIL Bond Index).                                                                   |
# | **NAV**                         | Net Asset Value – the per-unit price of the fund; calculated as (Total Assets - Liabilities) / Number of Units.                                                |
# | **52 Week High (NAV)**          | The highest Net Asset Value of the fund during the past 52 weeks.                                                                                              |
# | **52 Week Low (NAV)**           | The lowest Net Asset Value of the fund during the past 52 weeks.                                                                                               |
# | **Return (%) 1 mo**             | Percentage return generated by the fund over the last 1 month.                                                                                                 |
# | **Return (%) 3 mo**             | Percentage return generated by the fund over the last 3 months.                                                                                                |
# | **Return (%) 6 mo**             | Percentage return generated by the fund over the last 6 months.                                                                                                |
# | **Return (%) 1 yr**             | Percentage return generated by the fund over the last 1 year.                                                                                                  |
# | **Return (%) 2 yrs**            | Annualized return of the fund over the last 2 years.                                                                                                           |
# | **Return (%) 3 yrs**            | Annualized return of the fund over the last 3 years.                                                                                                           |
# | **Return (%) 5 yrs**            | Annualized return of the fund over the last 5 years.                                                                                                           |
# | **Return (%) 10 yrs**           | Annualized return of the fund over the last 10 years.                                                                                                          |
# | **PE Ratio**                    | Price-to-Earnings Ratio – indicates how much investors are paying for ₹1 of the fund’s earnings. Lower values may indicate undervaluation.                     |
# | **PB Ratio**                    | Price-to-Book Ratio – compares the market value to the book value of the fund’s holdings; used to assess valuation levels.                                     |
# | **Turnover Ratio (%)**          | Measures how frequently securities within the fund are traded in a year; higher ratios imply more active management.                                           |
# | **No. of Stocks**               | The number of individual stock holdings in the fund’s portfolio.                                                                                               |
# | **Avg. Market Cap (in Rs. cr)** | The average market capitalization of the companies in the fund; shows whether it focuses on large-cap, mid-cap, or small-cap stocks.                           |
# | **Large Cap (%)**               | Percentage of the portfolio invested in large-cap companies.                                                                                                   |
# | **Mid Cap (%)**                 | Percentage of the portfolio invested in mid-cap companies.                                                                                                     |
# | **Small Cap (%)**               | Percentage of the portfolio invested in small-cap companies.                                                                                                   |
# | **Highest Sector**              | The sector with the largest allocation within the fund (e.g., Financials, Technology).                                                                         |
# | **Avg. Maturity (in yrs)**      | For debt funds – the weighted average maturity period of all debt securities in the portfolio. Longer maturities imply higher interest rate sensitivity.       |
# | **Mod. Duration (in yrs)**      | Modified Duration – measures the sensitivity of a bond fund’s price to changes in interest rates.                                                              |
# | **Yield To Maturity (%)**       | The expected annual return of a debt fund if held until maturity, assuming no defaults.                                                                        |
# | **Alpha**                       | Measures the fund’s excess returns over its benchmark, adjusting for market risk. Higher alpha indicates better risk-adjusted performance.                     |
# | **Sharpe**                      | Sharpe Ratio – measures return per unit of total risk (standard deviation). Higher is better.                                                                  |
# | **Sortino**                     | Sortino Ratio – similar to Sharpe, but penalizes only downside risk (negative returns).                                                                        |
# | **Beta**                        | Measures the fund’s volatility relative to the market (benchmark). A beta > 1 indicates higher volatility.                                                     |
# | **Standard Deviation**          | Indicates the volatility of fund returns; higher values mean more risk.                                                                                        |
# | **Classification**              | Specifies the broad type of fund (e.g., Hybrid: Equity Oriented, Debt: Dynamic Bond).                                                                          |
# | **Exit Load**                   | The fee or charge payable if the investor redeems (sells) the fund units within a specific period.                                                             |
# | **Remarks**                     | Any additional notes or comments regarding the fund’s policy, exit load, or other conditions.                                                                  |
#
# ---

# %% [markdown]
# # **3. Problem Statement**
#
# - With over **2,000+ mutual fund schemes** in India and retail investors holding **60%+ of total AUM**, choosing the right fund has become increasingly overwhelming.
#
# - A SEBI survey revealed that only [**36% of investors**](https://www.financialexpress.com/market/sebi-survey-finds-9-5-households-invest-in-securities-3994956/?utm_source=chatgpt.com) have moderate or high knowledge of financial markets — meaning two-thirds of investors are **“flying blind”** when selecting funds.
#
# - Most struggle to evaluate **returns, risk, expense ratios, and categories**, often relying on random tips or past performance.
#
# - This highlights the need for an **AI-powered Mutual Fund Recommendation System** that can analyze data intelligently, match investor goals and risk appetite, and recommend the most suitable, risk-optimized funds — making smart investing simple, data-driven, and accessible for everyone.

# %% [markdown]
# ---

# %% [markdown]
# # **4. Task**
# The main task of this project is to develop an AI-based Mutual Fund Recommendation System that helps investors identify the most suitable mutual funds based on their risk profile, investment horizon, and return expectations.
#
# The system leverages data on fund performance, risk metrics, expense ratios, and category classifications to generate intelligent, data-driven recommendations.

# %% [markdown]
# ---

# %% [markdown]
# # **5. Objective**
#
# The objective of this project is to:
#
# *   Analyze mutual fund performance data across multiple time horizons (1, 3, 5, and 10 years).
# *   Evaluate each fund’s risk, return, and consistency using quantitative features like returns, ranks, ratings, and expense ratios.
#
# *   Build a recommendation model that suggests the best-performing and risk-optimized mutual funds for a given investor profile.
# *   Provide explainable insights, enabling users to understand why a particular fund is recommended — enhancing transparency and trust.
#
#
#
# Ultimately, this project aims to empower retail investors with an intelligent, data-driven tool to make smarter and more personalized investment decisions in the Indian mutual fund market.

# %% [markdown]
# ---

# %% [markdown]
# # **6. Import Libraries**

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp
from scipy import stats

# %% [markdown]
# ---

# %% [markdown]
# # **7. Data Loading and Exploration**

# %%
data = pd.read_csv('/content/screener.csv')

# Let's have a look on top 5 rows of the data
data.head()
# Out:
#                                                Funds   Fund Manager Category  \
# 0                360 ONE Balanced Hybrid Fund-Reg(G)    Mayur Patel    HY-EQ
# 1                   360 ONE Dynamic Bond Fund-Reg(G)     Milan Mody   DT-DYN
# 2  360 ONE ELSS Tax Saver Nifty 50 Index Fund-Reg(G)  Ashish Ongari  EQ-ELSS
# 3                       360 ONE Flexicap Fund-Reg(G)    Mayur Patel  EQ-FLEX
# 4                        360 ONE Focused Fund-Reg(G)    Mayur Patel   EQ-MLC
#
#   RupeeVestRating AUM(in Rs. cr) ExpenseRatio (%)   Fund Type Inception Date  \
# 0         Unrated          862.5             1.95  Open Ended      25-Sep-23
# 1               2          639.3             0.52  Open Ended      24-Jun-13
# 2         Unrated           87.6             0.52  Open Ended      28-Dec-22
# 3         Unrated         2008.3             1.99  Open Ended      30-Jun-23
# 4               4         7279.6             1.79  Open Ended      30-Oct-14
#
#                               Benchmark Index   NAV   ...  \
# 0  NIFTY 50 Hybrid Composite Debt 50:50 Index  12.84  ...
# 1                   CRISIL Dynamic Bond Index  23.14  ...
# 2                              NIFTY 50 - TRI  14.41  ...
# 3                               BSE 500 - TRI  15.37  ...
# 4                               BSE 500 - TRI   47.6  ...
#
#   Avg. Maturity(in yrs) Mod. Duration(in yrs) Yield To Maturity (%)  Alpha  \
# 0                  3.46                     -                  6.74   0.15
# 1                  7.03                     -                  7.19   0.03
# 2                     -                     -                     -  -0.05
# 3                     -                     -                     -   0.32
# 4                     -                     -                     -   0.15
#
#   Sharpe Sortino  Beta Standard Deviation              classification  \
# 0   0.27    0.59   0.5               6.69    Hybrid : Equity Oriented
# 1   0.29    0.58  0.87               1.86         Debt : Dynamic Bond
# 2   0.21    0.45  0.99              11.02  Equity : Tax Saving (ELSS)
# 3   0.29    0.57  1.03              13.83          Equity : Flexi Cap
# 4   0.26    0.52  0.89               11.6          Equity : Multi Cap
#
#                                    Exit_load_Remarks
# 0  Nil upto 10% of units and 1% for remaining uni...
# 1                                                Nil
# 2                                                Nil
# 3                1% on or before 365D Nil after 365D
# 4                                1% on or before 12M
#
# [5 rows x 39 columns]

# %%
#Shape of the data
data.shape
# Out:
# (1898, 39)

# %%
#Let's have a look on the columns and their data types using detailed info function
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1898 entries, 0 to 1897
# Data columns (total 39 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Funds                       1898 non-null   object
#  1   Fund Manager                1898 non-null   object
#  2   Category                    1898 non-null   object
#  3   RupeeVestRating             1898 non-null   object
#  4   AUM(in Rs. cr)              1898 non-null   object
#  5   ExpenseRatio (%)            1898 non-null   object
#  6   Fund Type                   1898 non-null   object
#  7   Inception Date              1898 non-null   object
#  8   Benchmark Index             1898 non-null   object
#  9    NAV                        1898 non-null   object
#  10   52 WeekHigh (NAV)          1898 non-null   object
#  11   52 WeekLow (NAV)           1898 non-null   object
#  12  Return (%)1 mo              1898 non-null   object
#  13  Return (%)3 mo              1898 non-null   object
#  14  Return (%)6 mo              1898 non-null   object
#  15  Return (%)1 yr              1898 non-null   object
#  16  Return (%)2 yrs             1898 non-null   object
#  17  Return (%)3 yrs             1898 non-null   object
#  18  Return (%)5 yrs             1898 non-null   object
#  19  Return (%)10 yrs            1898 non-null   object
#  20  PE Ratio                    1898 non-null   object
#  21  PB Ratio                    1898 non-null   object
#  22  Turnover Ratio (%)          1898 non-null   object
#  23   No. ofStocks               1898 non-null   object
#  24  Avg. Market Cap(in Rs. cr)  1898 non-null   object
#  25  Large Cap(%)                1898 non-null   object
#  26  Mid Cap(%)                  1898 non-null   object
#  27  Small Cap(%)                1898 non-null   object
#  28  Highest Sector              1898 non-null   object
#  29  Avg. Maturity(in yrs)       1898 non-null   object
#  30  Mod. Duration(in yrs)       1898 non-null   object
#  31  Yield To Maturity (%)       1898 non-null   object
#  32  Alpha                       1898 non-null   object
#  33  Sharpe                      1898 non-null   object
#  34  Sortino                     1898 non-null   object
#  35  Beta                        1898 non-null   object
#  36  Standard Deviation          1898 non-null   object
#  37  classification              1898 non-null   object
#  38  Exit_load_Remarks           1640 non-null   object
# dtypes: object(39)
# memory usage: 578.4+ KB

# %%
#Lets check the null values of the data
data.isna().sum()
# Out:
# Funds                           0
# Fund Manager                    0
# Category                        0
# RupeeVestRating                 0
# AUM(in Rs. cr)                  0
# ExpenseRatio (%)                0
# Fund Type                       0
# Inception Date                  0
# Benchmark Index                 0
#  NAV                            0
#  52 WeekHigh (NAV)              0
#  52 WeekLow (NAV)               0
# Return (%)1 mo                  0
# Return (%)3 mo                  0
# Return (%)6 mo                  0
# Return (%)1 yr                  0
# Return (%)2 yrs                 0
# Return (%)3 yrs                 0
# Return (%)5 yrs                 0
# Return (%)10 yrs                0
# PE Ratio                        0
# PB Ratio                        0
# Turnover Ratio (%)              0
#  No. ofStocks                   0
# Avg. Market Cap(in Rs. cr)      0
# Large Cap(%)                    0
# Mid Cap(%)                      0
# Small Cap(%)                    0
# Highest Sector                  0
# Avg. Maturity(in yrs)           0
# Mod. Duration(in yrs)           0
# Yield To Maturity (%)           0
# Alpha                           0
# Sharpe                          0
# Sortino                         0
# Beta                            0
# Standard Deviation              0
# classification                  0
# Exit_load_Remarks             258
# dtype: int64

# %% [markdown]
# # Observation:
#
#
#
#
# 1.   The dataset consists of **1,898 rows** and **39 columns**.
#
# 2.   **258 rows** have missing values in the **Exit_Load_Remarks** column.
#
# 3.   Currently, all **39 columns** are stored as the **object** data type. This is problematic for analysis and modeling.
#
# 4.   **Exit_Remarks** has many nulls and adds no value — so it will be dropped.

# %% [markdown]
# ---

# %% [markdown]
# # **8. Changing Datatypes**

# %%
# Drop 'Exit_load_Remarks'
data=data.drop('Exit_load_Remarks', axis=1)

# %%
#fetching name of the columns
data.columns = data.columns.str.strip()
data.columns
# Out:
# Index(['Funds', 'Fund Manager', 'Category', 'RupeeVestRating',
#        'AUM(in Rs. cr)', 'ExpenseRatio (%)', 'Fund Type', 'Inception Date',
#        'Benchmark Index', 'NAV', '52 WeekHigh (NAV)', '52 WeekLow (NAV)',
#        'Return (%)1 mo', 'Return (%)3 mo', 'Return (%)6 mo', 'Return (%)1 yr',
#        'Return (%)2 yrs', 'Return (%)3 yrs', 'Return (%)5 yrs',
#        'Return (%)10 yrs', 'PE Ratio', 'PB Ratio', 'Turnover Ratio (%)',
#        'No. ofStocks', 'Avg. Market Cap(in Rs. cr)', 'Large Cap(%)',
#        'Mid Cap(%)', 'Small Cap(%)', 'Highest Sector', 'Avg. Maturity(in yrs)',
#        'Mod. Duration(in yrs)', 'Yield To Maturity (%)', 'Alpha', 'Sharpe',
#        'Sortino', 'Beta', 'Standard Deviation', 'classification'],
#       dtype='object')

# %%
# numerical columns
num_cols = ['RupeeVestRating', 'AUM(in Rs. cr)', 'ExpenseRatio (%)',
            'NAV','52 WeekHigh (NAV)', '52 WeekLow (NAV)',
            'Return (%)1 mo', 'Return (%)3 mo', 'Return (%)6 mo',
            'Return (%)1 yr', 'Return (%)2 yrs', 'Return (%)3 yrs',
            'Return (%)5 yrs', 'Return (%)10 yrs', 'PE Ratio',
            'PB Ratio', 'Turnover Ratio (%)', 'No. ofStocks',
            'Avg. Market Cap(in Rs. cr)', 'Large Cap(%)', 'Mid Cap(%)',
            'Small Cap(%)','Avg. Maturity(in yrs)', 'Mod. Duration(in yrs)',
            'Yield To Maturity (%)', 'Alpha', 'Sharpe',
            'Sortino', 'Beta', 'Standard Deviation']

# %%
#Changing data type ofnumerical columns to
data[num_cols] = (
    data[num_cols]
    .replace(['--', '-', 'NA', 'N/A', 'n/a', 'na','Unrated'], np.nan)
    .replace({',': '', '%': ''}, regex=True)
    .astype(float)
)

# %%
#categorical columns
cat_cols = [i for i in data.columns if i not in num_cols]
cat_cols
# Out:
# ['Funds',
#  'Fund Manager',
#  'Category',
#  'Fund Type',
#  'Inception Date',
#  'Benchmark Index',
#  'Highest Sector',
#  'classification']

# %%
#Changing the black values in categorical columns to nan
data[cat_cols] = (
    data[cat_cols]
    .replace(['--', '-', 'NA', 'N/A', 'n/a', 'na','Nil','NIL','null'], np.nan)
)

# %%
#Checking the changes in the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1898 entries, 0 to 1897
# Data columns (total 38 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Funds                       1898 non-null   object
#  1   Fund Manager                1898 non-null   object
#  2   Category                    1898 non-null   object
#  3   RupeeVestRating             592 non-null    float64
#  4   AUM(in Rs. cr)              1861 non-null   float64
#  5   ExpenseRatio (%)            1857 non-null   float64
#  6   Fund Type                   1898 non-null   object
#  7   Inception Date              1876 non-null   object
#  8   Benchmark Index             1898 non-null   object
#  9   NAV                         1876 non-null   float64
#  10  52 WeekHigh (NAV)           1876 non-null   float64
#  11  52 WeekLow (NAV)            1876 non-null   float64
#  12  Return (%)1 mo              1861 non-null   float64
#  13  Return (%)3 mo              1824 non-null   float64
#  14  Return (%)6 mo              1747 non-null   float64
#  15  Return (%)1 yr              1612 non-null   float64
#  16  Return (%)2 yrs             1397 non-null   float64
#  17  Return (%)3 yrs             1215 non-null   float64
#  18  Return (%)5 yrs             919 non-null    float64
#  19  Return (%)10 yrs            654 non-null    float64
#  20  PE Ratio                    1126 non-null   float64
#  21  PB Ratio                    1126 non-null   float64
#  22  Turnover Ratio (%)          1600 non-null   float64
#  23  No. ofStocks                1204 non-null   float64
#  24  Avg. Market Cap(in Rs. cr)  1168 non-null   float64
#  25  Large Cap(%)                1137 non-null   float64
#  26  Mid Cap(%)                  1067 non-null   float64
#  27  Small Cap(%)                913 non-null    float64
#  28  Highest Sector              1168 non-null   object
#  29  Avg. Maturity(in yrs)       667 non-null    float64
#  30  Mod. Duration(in yrs)       601 non-null    float64
#  31  Yield To Maturity (%)       691 non-null    float64
#  32  Alpha                       1553 non-null   float64
#  33  Sharpe                      1611 non-null   float64
#  34  Sortino                     1610 non-null   float64
#  35  Beta                        1613 non-null   float64
#  36  Standard Deviation          1613 non-null   float64
#  37  classification              1898 non-null   object
# dtypes: float64(30), object(8)
# memory usage: 563.6+ KB

# %%
#Checking null values again
data.isna().sum()
# Out:
# Funds                            0
# Fund Manager                     0
# Category                         0
# RupeeVestRating               1306
# AUM(in Rs. cr)                  37
# ExpenseRatio (%)                41
# Fund Type                        0
# Inception Date                  22
# Benchmark Index                  0
# NAV                             22
# 52 WeekHigh (NAV)               22
# 52 WeekLow (NAV)                22
# Return (%)1 mo                  37
# Return (%)3 mo                  74
# Return (%)6 mo                 151
# Return (%)1 yr                 286
# Return (%)2 yrs                501
# Return (%)3 yrs                683
# Return (%)5 yrs                979
# Return (%)10 yrs              1244
# PE Ratio                       772
# PB Ratio                       772
# Turnover Ratio (%)             298
# No. ofStocks                   694
# Avg. Market Cap(in Rs. cr)     730
# Large Cap(%)                   761
# Mid Cap(%)                     831
# Small Cap(%)                   985
# Highest Sector                 730
# Avg. Maturity(in yrs)         1231
# Mod. Duration(in yrs)         1297
# Yield To Maturity (%)         1207
# Alpha                          345
# Sharpe                         287
# Sortino                        288
# Beta                           285
# Standard Deviation             285
# classification                   0
# dtype: int64

# %% [markdown]
# # Observation:
#
#
#
#
# 1.   **"Fund Type"** Single repeated value → adds no variance → drop.
#
# 2.   **13 columns** have more than **40% missing** values, there is no point of them to keep it.
#
#
#
# * 'RupeeVestRating'
# * 'Return (%)5 yrs'
# * 'Return (%)10 yrs'
# * 'Avg. Maturity(in yrs)'
# * 'Market Cap(in Rs. cr)'
# * 'Mod. Duration(in yrs)'
# * 'Yield To Maturity (%)'
# * 'Large Cap(%)'
# * 'Mid Cap(%)'
# * 'Small Cap(%)'
# * 'PE Ratio'
# * 'PB Ratio'
# * 'Highest Sector'

# %% [markdown]
# ---

# %% [markdown]
# # **9. Handling Missing and Duplicate Values**

# %%
# Drop 'columns which has more than 40% missing values - total 13 columns
data=data.drop(['Fund Type','RupeeVestRating','Return (%)5 yrs','Return (%)10 yrs',
                'PE Ratio','PB Ratio','Avg. Market Cap(in Rs. cr)',
                'Large Cap(%)', 'Mid Cap(%)', 'Small Cap(%)','Highest Sector',
                'Avg. Maturity(in yrs)', 'Mod. Duration(in yrs)', 'Yield To Maturity (%)'], axis=1)

# %%
#Checking remaining columns
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1898 entries, 0 to 1897
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Funds               1898 non-null   object
#  1   Fund Manager        1898 non-null   object
#  2   Category            1898 non-null   object
#  3   AUM(in Rs. cr)      1861 non-null   float64
#  4   ExpenseRatio (%)    1857 non-null   float64
#  5   Inception Date      1876 non-null   object
#  6   Benchmark Index     1898 non-null   object
#  7   NAV                 1876 non-null   float64
#  8   52 WeekHigh (NAV)   1876 non-null   float64
#  9   52 WeekLow (NAV)    1876 non-null   float64
#  10  Return (%)1 mo      1861 non-null   float64
#  11  Return (%)3 mo      1824 non-null   float64
#  12  Return (%)6 mo      1747 non-null   float64
#  13  Return (%)1 yr      1612 non-null   float64
#  14  Return (%)2 yrs     1397 non-null   float64
#  15  Return (%)3 yrs     1215 non-null   float64
#  16  Turnover Ratio (%)  1600 non-null   float64
#  17  No. ofStocks        1204 non-null   float64
#  18  Alpha               1553 non-null   float64
#  19  Sharpe              1611 non-null   float64
#  20  Sortino             1610 non-null   float64
#  21  Beta                1613 non-null   float64
#  22  Standard Deviation  1613 non-null   float64
#  23  classification      1898 non-null   object
# dtypes: float64(18), object(6)
# memory usage: 356.0+ KB

# %%
#Checking missing values in remaining columns
data.isna().sum()
# Out:
# Funds                   0
# Fund Manager            0
# Category                0
# AUM(in Rs. cr)         37
# ExpenseRatio (%)       41
# Inception Date         22
# Benchmark Index         0
# NAV                    22
# 52 WeekHigh (NAV)      22
# 52 WeekLow (NAV)       22
# Return (%)1 mo         37
# Return (%)3 mo         74
# Return (%)6 mo        151
# Return (%)1 yr        286
# Return (%)2 yrs       501
# Return (%)3 yrs       683
# Turnover Ratio (%)    298
# No. ofStocks          694
# Alpha                 345
# Sharpe                287
# Sortino               288
# Beta                  285
# Standard Deviation    285
# classification          0
# dtype: int64

# %% [markdown]
# # Observation:
#
#
# **Issue:** The "**Return (%)3 yrs**" column has a high volume of missing (null) values.
#
# **Action:** Rows with null 3-year returns were removed from the dataset.
#
# **Justification:**
#
# - The missing data cannot be reliably estimated.
#
# - The column itself is too valuable to drop, as **3-year returns are standard benchmarks** for fund analysis.

# %%
#Dropping rows where 3-year returns are null
data = data.dropna(subset=['Return (%)3 yrs'])

# %%
#Checking null values
data.isna().sum()
# Out:
# Funds                   0
# Fund Manager            0
# Category                0
# AUM(in Rs. cr)          0
# ExpenseRatio (%)        0
# Inception Date          0
# Benchmark Index         0
# NAV                     0
# 52 WeekHigh (NAV)       0
# 52 WeekLow (NAV)        0
# Return (%)1 mo          0
# Return (%)3 mo          0
# Return (%)6 mo          0
# Return (%)1 yr          0
# Return (%)2 yrs         1
# Return (%)3 yrs         0
# Turnover Ratio (%)    109
# No. ofStocks          462
# Alpha                  53
# Sharpe                  1
# Sortino                 3
# Beta                    0
# Standard Deviation      0
# classification          0
# dtype: int64

# %%
#checking how many null values till we have
data.shape
# Out:
# (1215, 24)

# %% [markdown]
# # Observation:
#
# **Column Dropping**
#
# The following two columns were dropped due to high or critical levels of missing data:
#
# - **"No. of Stocks"**: Dropped due to an excessive number of 462 missing values, rendering the column largely unusable for analysis.
#
# - **"Turnover Ratio (%)"**: Dropped despite only 109 missing values. The data is highly specific to individual fund strategies, meaning imputation (e.g., using an average) would introduce significant and unacceptable bias.
#
# **Row Exclusion (Listwise Deletion)**
#
# Rows containing missing values in the following four key metric columns were excluded (or dropped) from the dataset. The total number of affected rows is minimal, allowing for listwise deletion without substantial data loss:
#
# - **'Alpha'**: 53 missing values.
#
# - **'Sortino'**: 3 missing values.
#
# - **'Return (%) 2 yrs'**: 1 missing value.
#
# - **'Sharpe'**: 1 missing value.

# %%
#We are dropping two columns due to missing data
data = data.drop(['Turnover Ratio (%)','No. ofStocks'], axis=1)

#Dropping rows wherev Alpha, Return (%)2 yrs, Sharpe, Sortino are null
data = data.dropna(subset=['Alpha','Return (%)2 yrs','Sharpe','Sortino'])

# %%
#Checking null values
data.isna().sum()
# Out:
# Funds                 0
# Fund Manager          0
# Category              0
# AUM(in Rs. cr)        0
# ExpenseRatio (%)      0
# Inception Date        0
# Benchmark Index       0
# NAV                   0
# 52 WeekHigh (NAV)     0
# 52 WeekLow (NAV)      0
# Return (%)1 mo        0
# Return (%)3 mo        0
# Return (%)6 mo        0
# Return (%)1 yr        0
# Return (%)2 yrs       0
# Return (%)3 yrs       0
# Alpha                 0
# Sharpe                0
# Sortino               0
# Beta                  0
# Standard Deviation    0
# classification        0
# dtype: int64

# %%
#Checking final shape
data.shape
# Out:
# (1158, 22)

# %%
#Checking overall duplicated values
data.duplicated().any()
# Out:
# np.False_

# %% [markdown]
# # **Milestone 1**:
#
# Handled all the missing values form the data
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# # **10. Data Analysis and Visualization**

# %% [markdown]
# # **10.1 Univariate, Bivariate and Multivariate Analysis**

# %%
#Checking numerical columns
data.describe()
# Out:
#        AUM(in Rs. cr)  ExpenseRatio (%)           NAV  52 WeekHigh (NAV)  \
# count     1158.000000       1158.000000   1158.000000        1158.000000
# mean      5715.617444          1.251131    354.580717         359.170579
# std      11651.962953          0.740205    932.634770         949.380044
# min          1.200000          0.010000      8.460000           8.460000
# 25%        340.575000          0.520000     21.740000          22.145000
# 50%       1512.850000          1.265000     44.045000          45.320000
# 75%       5738.150000          1.900000    156.837500         166.612500
# max     119723.300000          2.640000  10880.800000       11657.200000
#
#        52 WeekLow (NAV)  Return (%)1 mo  Return (%)3 mo  Return (%)6 mo  \
# count       1158.000000     1158.000000     1158.000000     1158.000000
# mean         315.773057        1.621149        3.660898        8.209154
# std          812.092432        1.569596        4.684541        8.647036
# min            5.750000      -12.200000       -3.450000       -2.790000
# 25%           18.262500        0.520000        1.340000        3.180000
# 50%           37.665000        1.660000        2.585000        5.900000
# 75%          134.662500        2.690000        4.000000        9.747500
# max         6678.720000        9.840000       30.050000       62.140000
#
#        Return (%)1 yr  Return (%)2 yrs  Return (%)3 yrs        Alpha  \
# count     1158.000000      1158.000000      1158.000000  1158.000000
# mean         8.177850        16.038636        14.576796     0.189724
# std         10.813779         8.477577         7.464904     0.501421
# min        -14.380000        -2.340000         1.710000    -1.180000
# 25%          4.055000         8.252500         7.822500    -0.050000
# 50%          6.590000        15.840000        13.510000     0.030000
# 75%          8.080000        20.480000        18.597500     0.210000
# max         81.730000        67.490000        71.070000     3.880000
#
#             Sharpe      Sortino         Beta  Standard Deviation
# count  1158.000000  1158.000000  1158.000000         1158.000000
# mean      0.241192     0.469352     0.828187            9.333014
# std       0.211579     0.296235     0.357181            6.625731
# min      -2.190000    -0.800000    -0.510000            0.130000
# 25%       0.200000     0.320000     0.600000            2.042500
# 50%       0.260000     0.450000     0.920000           11.245000
# 75%       0.330000     0.610000     1.000000           13.830000
# max       0.770000     2.460000     4.640000           38.690000

# %%
#checking categorical columns
data.describe(include=['object'])
# Out:
#                                        Funds  Fund Manager Category  \
# count                                   1158          1158     1158
# unique                                  1158           324       49
# top     WOC Ultra Short Duration Fund-Reg(G)  Nishit Patel   EQ-ETF
# freq                                       1            32       98
#
#        Inception Date  Benchmark Index classification
# count            1158             1158           1158
# unique            916              208             49
# top         28-Dec-15  NIFTY 500 - TRI  Equity : ETFs
# freq                6              112             98

# %%
# Plot distribution of 3 yrs return%
plt.hist(data['Return (%)3 yrs'])
plt.xlabel('Return (%)3 yrs')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot distribution of AUM
plt.hist(data['AUM(in Rs. cr)'])
plt.xlabel('AUM(in Rs. cr)')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot distribution of ExpenseRatio
plt.hist(data['ExpenseRatio (%)'])
plt.xlabel('ExpenseRatio (%)')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot AUM vs. 3 yrs return%
plt.scatter(data['AUM(in Rs. cr)'], data['Return (%)3 yrs'])
plt.xlabel('AUM(in Rs. cr)')
plt.ylabel('Return (%)3 yrs')
plt.show()

# %%
# Plot distribution of Category
plt.hist(data['Category'].value_counts())
plt.xlabel('Category')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot NAV vs. 3 yrs return%
plt.scatter(data['NAV'], data['Return (%)3 yrs'])
plt.xlabel('NAV')
plt.ylabel('Return (%)3 yrs')
plt.show()

# %%
# Plot correlations between variables
plt.figure(figsize=(12, 8))
correlation_matrix = data.corr(numeric_only=True)
sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %% [markdown]
# # **10.2 Risk & Return Analysis**

# %% [markdown]
# # Q1. Which funds delivered the highest returns over 1 and 3 years?

# %%
# Create the bar chart
plt.barh(data.sort_values(by='Return (%)1 yr', ascending=False)['Funds'][:10], data.sort_values(by='Return (%)1 yr', ascending=False)['Return (%)1 yr'][:10])

# Add labels and title
plt.xlabel('Return (%)1 year')
plt.ylabel('Fund')
plt.title('Top 10 Mutual Fund by 1 Year Returns')


# Display the chart
plt.show()

# %%
# Create the bar chart
plt.barh(data.sort_values(by='Return (%)3 yrs', ascending=False)['Funds'][:10], data.sort_values(by='Return (%)3 yrs', ascending=False)['Return (%)3 yrs'][:10])

# Add labels and title
plt.xlabel('Return (%)3 year')
plt.ylabel('Fund')
plt.title('Top 10 Mutual Fund by 3 Year Returns')


# Display the chart
plt.show()

# %% [markdown]
# # Q2. Which categories delivered the highest returns over 3 years?

# %%
# Create the bar chart
top_10_cat = data.groupby(by='Category')['Return (%)3 yrs'].max().sort_values(ascending=False)[:10]
top_10_cat.plot(kind='barh', color='#1f77b4')

# Add labels and title
plt.title('Top 10 Fund Categories by Maximum 3-Year Return', fontsize=14)
plt.xlabel('Fund Category', fontsize=12)
plt.ylabel('Max 3-Year Return (%)', fontsize=12)

# Display the chart
plt.show()

# %% [markdown]
# # Q3. How does risk (Standard Deviation, Beta) relate to returns?

# %%
# Plot correlations between Standard Deviation, Beta and Returns
plt.figure(figsize=(6, 4))
correlation_matrix = data[['Beta','Standard Deviation','Return (%)1 yr','Return (%)3 yrs']].corr()
sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %% [markdown]
# # *Ans - Risk is Being Rewarded:* The market has historically rewarded the fund for taking on greater volatility (risk) with higher returns.

# %% [markdown]
# # Q4. Do higher-risk funds offer better risk-adjusted performance (Sharpe, Sortino)?

# %%
# Plot correlations between Sharpe, Sortino and Returns
plt.figure(figsize=(6, 4))
correlation_matrix = data[['Sharpe','Sortino']].corr()
sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %% [markdown]
# # *Ans:* Based on the $\mathbf{0.6}$ correlation alone, we cannot definitively conclude whether higher-risk funds offer better risk-adjusted performance

# %% [markdown]
# # Q5 Which funds have high alpha (outperformance over benchmark) with low volatility?

# %%
# Create the horizontal bar chart
top_10_funds = data.sort_values(by=['Alpha','Standard Deviation'], ascending=[False, True])[:10]

# Set the figure size to accommodate long labels
plt.figure(figsize=(10, 8))

# Bar width for grouping
bar_width = 0.25
r1 = np.arange(len(top_10_funds['Funds']))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]

# Plotting the three years' returns horizontally
plt.barh(r1, top_10_funds['Return (%)1 yr'], height=bar_width, label='1 Year Return')
plt.barh(r2, top_10_funds['Return (%)2 yrs'], height=bar_width, label='2 Years Return')
plt.barh(r3, top_10_funds['Return (%)3 yrs'], height=bar_width, label='3 Years Return')

# Set labels, title, and ticks
plt.title("Top 10 funds with high Alpha and low Volatility", fontsize=14)
plt.ylabel("Funds") # Now the y-axis has the fund names
plt.xlabel("Return (%)") # And the x-axis has the numeric values

# Set the fund names as the y-axis tick labels
plt.yticks([r + bar_width for r in r1], top_10_funds['Funds'])

plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Q6 Is there a relationship between AUM size and fund performance?

# %%
# Plot correlations between Sharpe, Sortino and Returns
plt.figure(figsize=(6, 4))
correlation_matrix = data[['AUM(in Rs. cr)','Return (%)3 yrs']].corr()
sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %% [markdown]
# # *Ans:* Based on the $\mathbf{0.036}$ correlation, we can say that there is almost no correlation between AUM and returns.

# %% [markdown]
# # Q7 Which categories have the most efficient funds (high Sharpe, low Expense Ratio)?

# %%
# Calculate mean Sharpe and Expense Ratio for each category and sort
efficient_funds_by_category = data.groupby('Category')[['Sharpe', 'ExpenseRatio (%)']].mean().sort_values(by=['Sharpe', 'ExpenseRatio (%)'], ascending=[False, True])

# Display the top 10 categories
print("Top 10 Categories with High Sharpe and Low Expense Ratio:")
print(efficient_funds_by_category.head(10))
# Out:
# Top 10 Categories with High Sharpe and Low Expense Ratio:
#             Sharpe  ExpenseRatio (%)
# Category
# DT-MM     0.510476          0.410476
# GOLD-MF   0.462143          0.506429
# GOLD-ETF  0.440000          0.514118
# DT-FL     0.406667          0.672500
# DT-LOWD   0.381500          0.838500
# HY-MULTI  0.371000          1.740000
# EQ-AUTO   0.367500          1.802500
# EQ-PHRM   0.338000          2.097000
# FOF-DOM   0.327292          0.671875
# DT-CR     0.319333          1.528667

# %% [markdown]
# # Q8 Are expense ratios higher for certain categories, and do they correlate with returns?

# %%
# Plot correlations between Sharpe, Sortino and Returns
plt.figure(figsize=(6, 4))
correlation_matrix = data[['ExpenseRatio (%)','Return (%)3 yrs']].corr()
sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %% [markdown]
# # *Ans:* Based on the $\mathbf{0.18}$ correlation, we can say that there is almost no correlation between ExpenseRatio (%) and returns.

# %% [markdown]
# ---

# %% [markdown]
# # **11. Hypothesis Testing**

# %% [markdown]
# # **Test 1: Return vs Category**
# # H₀: Mean 3Y return is same across categories
# # H₁: At least one category differs

# %%
# Step 1: Group data by category
groups = [group['Return (%)3 yrs'].values for name, group in data.groupby('Category')]

# %%
# Step 2: Perform one-way ANOVA
f_stat, p_val = stats.f_oneway(*groups)

# %%
# Step 3: Print results
print("ANOVA Test: Return (%)3 yrs across Categories")
print(f"F-statistic: {f_stat:.4f}")
print(f"P-value: {p_val:.6f}")
# Out:
# ANOVA Test: Return (%)3 yrs across Categories
# F-statistic: 42.9362
# P-value: 0.000000

# %%
# Step 4: Interpretation
alpha = 0.05
if p_val < alpha:
    print("❌ Reject H₀: Mean 3-year returns differ significantly among categories.")
else:
    print("✅ Fail to reject H₀: No significant difference among category means.")
# Out:
# ❌ Reject H₀: Mean 3-year returns differ significantly among categories.

# %% [markdown]
# # **Milestone 2**:
#
# Data Analysis and Visualization
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# # **12. Feature Engineering**

# %% [markdown]
# # 12.1 Create "Class" Column
# #We created a 'class' column derived from the 'classification' column to establish broader categories. The original 'category' and 'classification' columns contained 49 unique values that needed consolidation.

# %%
# Create a class feature from classification to make identification easier
data['Class']=data['classification'].str.split().str[0]

# %%
#Lets see in each class how many funds are there
data['Class'].value_counts().plot(kind='bar')

# Add labels and title
plt.title('Class Frequency', fontsize=14)
plt.xlabel('Class Name', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

# Display the chart
plt.show()

# %%
#Converting "Class" into numeric column by label encoding
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['Class'] = le.fit_transform(data['Class'])

# %%
#Encoded class
print(le.classes_)
# Out:
# ['Debt' 'Equity' 'FoFs' 'Gold' 'Hybrid']

# %%
#Droping classification and Category
data = data.drop(['classification','Category'], axis=1)

# %% [markdown]
# # 12.2  Create "Num_of_years" column from Inception Date

# %%
from datetime import datetime

# Convert to datetime and calculate years
data['No_of_years'] = (pd.to_datetime('today') - pd.to_datetime(data['Inception Date'])).dt.days / 365.25

# Round to 1 decimal place for cleaner output
data['No_of_years'] = data['No_of_years'].round(1)
# Out:
# /tmp/ipython-input-4189350799.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['No_of_years'] = (pd.to_datetime('today') - pd.to_datetime(data['Inception Date'])).dt.days / 365.25

# %%
data['No_of_years'][:5]
# Out:
# 1     12.4
# 4     11.1
# 6     12.0
# 9      4.0
# 11    14.6
# Name: No_of_years, dtype: float64

# %%
#Droping classification and Category
data = data.drop(['Inception Date'], axis=1)

# %% [markdown]
# # 12.3 Columns Removed:
#
# # 1) Benchmark Index - Removed due to high cardinality with limited predictive value
#
# # 2) Fund Manager - Removed due to excessive unique values
#
# # 3) 52 WeekHigh (NAV) and 52 WeekLow (NAV) almost similar to NAV

# %%
#Droping classification and Category
data = data.drop(['Benchmark Index','Fund Manager','52 WeekHigh (NAV)','52 WeekLow (NAV)'], axis=1)

# %% [markdown]
# # 12.4 Creating following columns
#
# 1) Average Annual Return (AAR)
# 2) Risk Score = average of normalized Beta and Std Dev
# 3) Return Score = percentile of Avg_Return
# 4) Fund Strength = combination of AUM and No_of_years
# 5) Expense Efficiency = Return(1yr) / Expense Ratio
# 6) Risk Adjusted Return (Sharpe + Sortino)
# 7) Overall Score

# %%
# Average Annual Return (AAR)
data['Avg_Return'] = data[['Return (%)1 yr','Return (%)2 yrs','Return (%)3 yrs']].mean(axis=1)

# Risk Score = average of normalized Beta and Std Dev
data['Risk_Score'] = (data['Beta'].rank(pct=True) + data['Standard Deviation'].rank(pct=True)) / 2

# Return Score = percentile of Avg_Return
data['Return_Score'] = data['Avg_Return'].rank(pct=True)

# Risk Adjusted Return (Sharpe + Sortino)
data['Risk_Adjusted'] = (data['Sharpe'].rank(pct=True) + data['Sortino'].rank(pct=True)) / 2

# Fund Strength = combination of AUM and No_of_years
data['Fund_Strength'] = (data['AUM(in Rs. cr)'].rank(pct=True) + data['No_of_years'].rank(pct=True)) / 2

# %%
data1 = data[['Class','Return_Score','Risk_Score','Risk_Adjusted']]
data1.head()
# Out:
#     Class  Return_Score  Risk_Score  Risk_Adjusted
# 1       0      0.361831    0.328584       0.660406
# 4       1      0.529361    0.485104       0.557858
# 6       0      0.094991    0.454663       0.354706
# 9       1      0.854922    0.879318       0.812392
# 11      2      0.631261    0.368523       0.816710

# %% [markdown]
# ---

# %% [markdown]
# # **13. Outlier Checking**

# %%
#Checking the data distribution
data1.describe()
# Out:
#              Class  Return_Score   Risk_Score  Risk_Adjusted
# count  1158.000000   1158.000000  1158.000000    1158.000000
# mean      1.270294      0.500432     0.500432       0.500432
# std       1.280260      0.288800     0.232370       0.262618
# min       0.000000      0.000864     0.011874       0.000864
# 25%       0.000000      0.250756     0.313310       0.301166
# 50%       1.000000      0.500216     0.538104       0.511010
# 75%       1.750000      0.750000     0.660568       0.705527
# max       4.000000      1.000000     0.997841       0.992876

# %%
plt.figure(figsize=(8, 6)) # Optional: Adjust figure size
sns.boxplot(data1)
plt.title('Boxplot of Whole Dataset')
plt.ylabel('Value')
plt.show()

# %% [markdown]
# # Observation:
#
# - There will no outliers found in any of the features

# %% [markdown]
# ---

# %% [markdown]
# # **14.Model Building**

# %%
#Importing models libraries
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.metrics import silhouette_score

# %% [markdown]
# # **K-Means Clustering**

# %%
# Initialize lists to store results
inertia = []
silhouette_scores = []
K = range(2, 15) # Using a smaller range for practical efficiency

# Run K-Means for each K
for k in K:
    # 1. Train the K-Means model
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=50)
    kmeans.fit(data1)

    # 2. Store the Inertia (WCSS)
    inertia.append(kmeans.inertia_)

    # 3. Store the Silhouette Score
    score = silhouette_score(data1, kmeans.labels_)
    silhouette_scores.append(score)

# --- Plotting the Results ---
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

## Plot 1: Inertia (Elbow Method)
ax1.plot(K, inertia, 'bo-')
ax1.set_xlabel('Number of Clusters (k)')
ax1.set_ylabel('Inertia (WCSS)')
ax1.set_title('1. Elbow Method for Optimal k (Inertia)')
ax1.grid(True)

## Plot 2: Silhouette Score
ax2.plot(K, silhouette_scores, 'ro-')
ax2.set_xlabel('Number of Clusters (k)')
ax2.set_ylabel('Silhouette Score')
ax2.set_title('2. Silhouette Analysis for Optimal k')
ax2.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Observation:
# Based on an analysis of both the Within-Cluster Sum of Squares (WCSS) and the Silhouette Score, the optimal number of clusters was determined to be **K = 4**.

# %%
#Decide the k=4 and retrain the model
kmeans = KMeans(n_clusters=4, random_state=42, n_init=20)
kmeans.fit_predict(data1)
# Out:
# array([3, 1, 3, ..., 3, 1, 3], dtype=int32)

# %%
#Checking value counts that how many mutual funds come under which cluster
clustered_users = pd.DataFrame(kmeans.labels_).reset_index()
clustered_users.rename(columns={0: 'cluster_label', 'index':'fund_no'}, inplace=True)
clustered_users['cluster_label'].value_counts()
# Out:
# cluster_label
# 1    542
# 3    326
# 2    159
# 0    131
# Name: count, dtype: int64

# %%
#Cluster 0 = FoFs and Gold  Funds | High Return |  Moderate Risk | High Risk Adjusted Returns
funds = data1.copy()

# Define the columns to be added from the original 'data' DataFrame
display_cols = ['Funds','AUM(in Rs. cr)','Return (%)1 yr','Return (%)2 yrs', 'Return (%)3 yrs','Beta','Standard Deviation','ExpenseRatio (%)','NAV']

# Concatenate these columns to the 'funds' DataFrame
funds = pd.concat([funds, data[display_cols]], axis=1)

funds['cluster'] = kmeans.labels_
Cluster_0 = funds[funds['cluster'] == 0].sort_values(by=['Return_Score', 'Risk_Score','Risk_Adjusted'], ascending=False)[:20]
Cluster_0 = Cluster_0[['Funds','Class','AUM(in Rs. cr)','Return (%)1 yr','Return (%)2 yrs', 'Return (%)3 yrs','Beta','Standard Deviation','ExpenseRatio (%)','NAV','cluster']]
Cluster_0.head()
# Out:
#                                                   Funds  Class  \
# 1245               Mirae Asset NYSE FANG+ETF FoF-Reg(G)      2
# 484   DSP World Gold Mining Overseas Equity Omni FoF...      2
# 1248          Mirae Asset S&P 500 Top 50 ETF FoF-Reg(G)      2
# 1188  Mirae Asset Global X Artificial Intelligence &...      2
# 107                          Aditya Birla SL Silver ETF      3
#
#       AUM(in Rs. cr)  Return (%)1 yr  Return (%)2 yrs  Return (%)3 yrs  Beta  \
# 1245          2347.4           81.73            67.49            71.07  0.47
# 484           1677.7           80.51            61.60            44.46  0.25
# 1248           752.0           55.57            48.07            40.60  0.30
# 1188           383.3           46.63            43.40            42.60  0.53
# 107           1580.2           52.39            41.96            33.55  0.12
#
#       Standard Deviation  ExpenseRatio (%)     NAV  cluster
# 1245               29.26              0.45   37.32        0
# 484                29.99              2.34   42.67        0
# 1248               21.42              0.49   25.01        0
# 1188               21.10              0.40   27.55        0
# 107                24.35              0.35  145.76        0

# %%
#Cluster 1 = Equity Funds | High Return | High Risk | High Risk Adjusted Returns
Cluster_1 = funds[funds['cluster'] == 1].sort_values(by=['Return_Score', 'Risk_Score','Risk_Adjusted'], ascending=False)[:20]
Cluster_1 = Cluster_1[['Funds','Class','AUM(in Rs. cr)','Return (%)1 yr','Return (%)2 yrs', 'Return (%)3 yrs','Beta','Standard Deviation','ExpenseRatio (%)','NAV','cluster']]
Cluster_1.head()
# Out:
#                                        Funds  Class  AUM(in Rs. cr)  \
# 1244              Mirae Asset NYSE FANG+ ETF      1          3491.9
# 1442  Nippon India Taiwan Equity Fund-Reg(G)      1           406.7
# 1287            Motilal Oswal Nasdaq 100 ETF      1         10804.1
# 836       ICICI Pru NASDAQ 100 Index Fund(G)      1          2543.9
# 1247          Mirae Asset S&P 500 Top 50 ETF      1           966.0
#
#       Return (%)1 yr  Return (%)2 yrs  Return (%)3 yrs  Beta  \
# 1244           49.31            53.07            60.85  0.88
# 1442           44.67            41.57            39.94  1.26
# 1287           34.30            35.31            36.44  0.97
# 836            33.77            34.87            35.38  0.98
# 1247           32.16            35.69            32.67  0.34
#
#       Standard Deviation  ExpenseRatio (%)     NAV  cluster
# 1244               26.45              0.65  145.04        1
# 1442               27.84              2.43   17.28        1
# 1287               17.98              0.58  220.14        1
# 836                17.89              1.07   19.59        1
# 1247               15.08              0.60   58.89        1

# %%
#Cluster 2 = Hybrid Fund |Moderate Return | Moderate Risk | Moderate Risk Adjusted Returns
Cluster_2 = funds[funds['cluster'] == 2].sort_values(by=['Return_Score', 'Risk_Score','Risk_Adjusted'], ascending=False)[:20]
Cluster_2 = Cluster_2[['Funds','Class','AUM(in Rs. cr)','Return (%)1 yr','Return (%)2 yrs', 'Return (%)3 yrs','Beta','Standard Deviation','ExpenseRatio (%)','NAV','cluster']]
Cluster_2.head()
# Out:
#                                                   Funds  Class  \
# 901       ICICI Pru Retirement Fund-Pure Equity Plan(G)      4
# 1579  SBI Magnum Childrens Benefit Fund-Investment P...      4
# 1403    Nippon India Multi Asset Allocation Fund-Reg(G)      4
# 1503               Quant Multi Asset Allocation Fund(G)      4
# 898   ICICI Pru Retirement Fund-Hybrid Aggressive Pl...      4
#
#       AUM(in Rs. cr)  Return (%)1 yr  Return (%)2 yrs  Return (%)3 yrs  Beta  \
# 901           1410.0           13.69            28.60            24.11  1.08
# 1579          4419.6           12.60            25.68            23.52  1.20
# 1403          7759.3           15.68            23.28            20.14  4.07
# 1503          3817.6           10.62            25.64            20.27  4.64
# 898            937.4           11.06            24.35            20.44  1.40
#
#       Standard Deviation  ExpenseRatio (%)     NAV  cluster
# 901                14.20              2.07   33.87        2
# 1579               13.22              1.85   44.81        2
# 1403                7.85              1.43   23.21        2
# 1503               11.36              1.85  151.27        2
# 898                12.16              2.19   26.81        2

# %%
#Cluster 3 =  Debt Funds | Less Return | Less Risk | Less Risk Adjusted Returns
Cluster_3 = funds[funds['cluster'] == 3].sort_values(by=['Return_Score', 'Risk_Score','Risk_Adjusted'], ascending=False)[:20]
Cluster_3 = Cluster_3[['Funds','Class','AUM(in Rs. cr)','Return (%)1 yr','Return (%)2 yrs', 'Return (%)3 yrs','Beta','Standard Deviation','ExpenseRatio (%)','NAV','cluster']]
Cluster_3.head()
# Out:
#                                         Funds  Class  AUM(in Rs. cr)  \
# 423               DSP Credit Risk Fund-Reg(G)      0           207.9
# 742              HSBC Credit Risk Fund-Reg(G)      0           562.4
# 26    Aditya Birla SL Credit Risk Fund-Reg(G)      0          1052.9
# 69    Aditya Birla SL Medium Term Plan-Reg(G)      0          2734.1
# 1399     Nippon India Medium Duration Fund(G)      0           119.9
#
#       Return (%)1 yr  Return (%)2 yrs  Return (%)3 yrs  Beta  \
# 423            21.58            14.47            14.87  0.18
# 742            20.62            13.66            11.25  0.66
# 26             13.43            12.77            10.80  0.15
# 69             11.24            11.01             9.65  0.36
# 1399           10.19             9.31             8.51  0.41
#
#       Standard Deviation  ExpenseRatio (%)    NAV  cluster
# 423                 7.61              1.20  50.45        3
# 742                 6.56              1.64  32.93        3
# 26                  2.49              1.54  23.05        3
# 69                  1.80              1.57  40.91        3
# 1399                1.91              1.01  16.10        3

# %%
#Final recommendation dataset
mutual_fund_recommendations = pd.concat([Cluster_0, Cluster_1, Cluster_2, Cluster_3])
mutual_fund_recommendations.to_csv('mutual_fund_recommendations.csv', index=False)

# %% [markdown]
# ---
